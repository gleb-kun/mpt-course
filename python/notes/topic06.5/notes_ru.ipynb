# %% [markdown]
# # Тема #6.5. Исследование функций

# %% [markdown]
# Цель: используя теоретические и практические знания из предыдущих конспектов и работ выполнить исследования различных функций.

# %% [markdown]
# ## Задания на самостоятельную работу

# %% [markdown]
# ### Задание 1. Исследование функции $y=f(x)$
#
# Цель: используя теоретические и практические знания из предыдущих конспектов и работ выполнить исследование функции $y=f(x)$.
#
# Синтаксис функций необходимо смотреть в предыдущих конспектах или в иных справочных системах (здесь даны только задачи и некоторые подсказки).
#
# Исследовать функции (все):
#
# - $y=\dfrac{x^3}{2(x+1)^2}$;
#
# - $y=1-\dfrac{x^2+2x+4}{2(x+2)}$;
#
# - $y=\dfrac{x^2}{x^2+3}$;
#
# - $y=\sqrt[3]{x(x-3)^2}$;
#
# - $y=xe^{-x^2}$.
#
# **Схема исследования функции:**
#
# - Исследовать непрерывность, найти точки разрыва и выяснить характер разрывов (написать область определения функции). Найти левые и правые пределы в точках разрыва.
#
# - Выяснить, не является ли функция чётной или нечётной;
# Необходимо проверить выполнения неравенств $y(-x)=-y(x)$, $y(-x)=y(x)$.
#
# - Найти точки пересечения с осями координат и интервалы знакопостоянства;
# Решить соответствующие уравнения.
#
# - Найти асимптоты графика функции;
# Уравнение наклонной асимптоты $y=kx+b,$ где коэффициенты вычисляются по формулам:
# $$
# k=\lim_{x\rightarrow +\infty}\frac{f(x)}{x}\quad\text{и}\quad b=\lim_{x\rightarrow\infty}(f(x)-kx).\tag{1}
# $$
# Аналогичные формулы для $x\rightarrow-\infty$ (обычно коэффициенты совпадают).
#
# - Исследовать монотонность функции и найти ее экстремумы;
# Монотонность – интервалы возрастания и убывания функции ($y'>0$ и $y'<0$).
#
# - Найти точки перегиба, установить интервалы выпуклости и вогнутости графика функции; интервалы выпуклости и вогнутости функции ($y''<0$ и $y''>0$).
#
# - Построить график функции (сплошная линия) и все асимптоты (пунктирные линии). Обозначить дополнительные точки графика функции: пересечения с осями (черные крестики), точки максимума (красные точки), минимума (синие точки) и перегиба (зеленые точки).

# %% [markdown]
# ### Задание 2. Нахождение касательной плоскости и нормали к поверхности
#
# Инструменты, которые понадобятся далее, находятся в библиотеке `matplotlib`.
#
# Ее надо подключить командой import:
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
# ```
#
# Также могут понадобиться дополнительные модули, например:
# `from matplotlib.patches import Circle, Ellipse`
# из `scipy.optimize import fsolve` (для неявных функций)
# из `mpl_toolkits.mplot3d import Axes3D` (для 3D-графиков)
#
# Некоторые из часто используемых команд:
#
# - Построение явно заданных функций: `plt.plot(x, y)`;
# - Построение неявно заданных функций: через `contour (plt.contour)` или использование `fsolve` из `scipy.optimize` для построения множества точек;
# - Совмещение нескольких графических объектов: использование нескольких вызовов `plt.plot/plt.scatter` в одном блоке и затем `plt.show()` или создание фигуры и осей через `plt.subplots()`;
# - Построение точек: `plt.scatter(x, y)` или `plt.plot(x, y, 'o')`;
# - Построение кривой в пространстве: `ax.plot3D(x(t), y(t), z(t))` или `fig = plt.figure()`; `ax = fig.add_subplot(111, projection='3d')`.

# %% [markdown]
# **Постановка:**
#
# Если поверхность задана уравнением
# $$F(x, y, z) = 0\tag{2},$$
# то есть неявно, то уравнение касательной плоскости к данной поверхности в точке
# $M_0(x_0, y_0, z_0)$ можно найти по следующей формуле:
# $$F'_x(M_0)(x - x_0) + F'_y(M_0)(y - y_0) + F'_z(M_0)(z - z_0) = 0.\tag{3}$$
#
# Уравнение нормали по точке $M_0(x_0,y_0,z_0)$:
# $$\frac{(x - x_0)}{F'_x(M_0)} = \frac{(y - y_0)}{F'_y(M_0)} = \frac{(z - z_0)}{F'_z(M_0)}.\tag{4}$$
#
# **Задания:**
#
# - Найти уравнения касательной плоскости и нормали к поверхности $6xy - 2x^2 - xy^2 - z^2 + 3 = 0$
# в точке $M_0(1, 2, 3)$. Построить графики поверхности, точки и плоскости.
#
# - Найти уравнения касательной плоскости и нормали к поверхности $xy + e^{xz} = 0$ в точке $M_0(5, -\frac{1}{5}, 0)$. Построить графики поверхности, точки и плоскости.
